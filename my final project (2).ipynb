# %%
import pandas as pd
import numpy as np

# %%
mydata1=pd.read_csv(r"D:\DataSets-master\garry_data.csv")
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mydata1.dtypes
# Out:
# id            int64
# time\t      float64
# R1           object
# R2           object
# R3           object
# R4           object
# R5           object
# R6           object
# R7           object
# R8           object
# Temp.        object
# Humidity     object
# dtype: object

# %%
mydata1
# Out:
#         id    time\t       R1       R2       R3       R4       R5       R6  \
# 0        0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423
# 1        0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412
# 2        0 -0.999194  12.8607  10.3686   10.437  11.6696  13.4924  13.3405
# 3        0 -0.998916  12.8602  10.3686   10.437  11.6697  13.4921  13.3398
# 4        0 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919   13.339
# 5        0 -0.998349  12.8594  10.3691  10.4376  11.6702  13.4921  13.3382
# 6        0 -0.998071  12.8595  10.3695  10.4378  11.6702  13.4919  13.3377
# 7        0 -0.997793  12.8587  10.3696  10.4372  11.6698  13.4916  13.3371
# 8        0 -0.997515  12.8579  10.3693  10.4365  11.6694  13.4914  13.3365
# 9        0 -0.997227  12.8573  10.3692  10.4362  11.6693  13.4912  13.3364
# 10       0 -0.996948  12.8569  10.3695  10.4362  11.6692  13.4913  13.3359
# ...

# %%
mydata2=pd.read_csv(r"D:\DataSets-master\metan_data.csv")

# %%
mydata2
# Out:
#     id      date       class     t0    dt
# 0    0  07-04-15      banana  13.49  1.64
# 1    1  07-05-15        wine  19.61  0.54
# 2    2  07-06-15        wine  19.99  0.66
# 3    3  07-09-15      banana   6.49  0.72
# 4    4  07-09-15        wine  20.07  0.53
# 5    5  07-10-15      banana  16.38  0.80
# 6    6  07-11-15        wine  11.19  0.95
# 7    7  07-12-15      banana   8.17  0.49
# 8    8  07-12-15        wine  10.41  1.17
# 9    9  07-15-15      banana   9.35  0.61
# 10  10  07-15-15      banana  12.70  1.18
# 11  11  07-17-15      banana  14.85  0.60
# 12  12  07-19-15        wine  11.47  0.38
# 13  13  07-21-15      banana   8.00  0.48
# 14  14  07-21-15        wine  23.62  0.38
# 15  15  07-22-15      banana  16.54  0.72
# 16  16  07-22-15      banana  20.60  1.32
# 17  17  07-23-15      banana   6.54  0.64
# 18  18  07-23-15      banana  20.22  0.44
# 19  19  07-23-15        wine  22.54  0.79
# 20  20  07-24-15        wine  17.40  1.18
# ...

# %%
mydata=pd.merge(mydata1,mydata2,how='left')

# %%
mydata.dtypes
# Out:
# id            int64
# time\t      float64
# R1           object
# R2           object
# R3           object
# R4           object
# R5           object
# R6           object
# R7           object
# R8           object
# Temp.        object
# Humidity     object
# date         object
# class        object
# t0          float64
# dt          float64
# dtype: object

# %%
mydata
for i in range(1,9):
    mydata['R'+str(i)]=mydata['R'+str(i)].convert_objects(convert_numeric=True)
mydata['Temp.']=mydata['Temp.'].convert_objects(convert_numeric=True)
mydata['Humidity']=mydata['Humidity'].convert_objects(convert_numeric=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# ...

# %%
mydata
# Out:
#         id    time\t       R1       R2       R3       R4       R5       R6  \
# 0        0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423
# 1        0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412
# 2        0 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924  13.3405
# 3        0 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921  13.3398
# 4        0 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919  13.3390
# 5        0 -0.998349  12.8594  10.3691  10.4376  11.6702  13.4921  13.3382
# 6        0 -0.998071  12.8595  10.3695  10.4378  11.6702  13.4919  13.3377
# 7        0 -0.997793  12.8587  10.3696  10.4372  11.6698  13.4916  13.3371
# 8        0 -0.997515  12.8579  10.3693  10.4365  11.6694  13.4914  13.3365
# 9        0 -0.997227  12.8573  10.3692  10.4362  11.6693  13.4912  13.3364
# 10       0 -0.996948  12.8569  10.3695  10.4362  11.6692  13.4913  13.3359
# ...

# %%
x_input1=mydata.drop(["class"],axis=1)

# %%
x_input1
# Out:
#         id    time\t       R1       R2       R3       R4       R5       R6  \
# 0        0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423
# 1        0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412
# 2        0 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924  13.3405
# 3        0 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921  13.3398
# 4        0 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919  13.3390
# 5        0 -0.998349  12.8594  10.3691  10.4376  11.6702  13.4921  13.3382
# 6        0 -0.998071  12.8595  10.3695  10.4378  11.6702  13.4919  13.3377
# 7        0 -0.997793  12.8587  10.3696  10.4372  11.6698  13.4916  13.3371
# 8        0 -0.997515  12.8579  10.3693  10.4365  11.6694  13.4914  13.3365
# 9        0 -0.997227  12.8573  10.3692  10.4362  11.6693  13.4912  13.3364
# 10       0 -0.996948  12.8569  10.3695  10.4362  11.6692  13.4913  13.3359
# ...

# %%
x_input=x_input1.drop(["date"],axis=1)

# %%
x_input
# Out:
#         id    time\t       R1       R2       R3       R4       R5       R6  \
# 0        0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423
# 1        0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412
# 2        0 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924  13.3405
# 3        0 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921  13.3398
# 4        0 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919  13.3390
# 5        0 -0.998349  12.8594  10.3691  10.4376  11.6702  13.4921  13.3382
# 6        0 -0.998071  12.8595  10.3695  10.4378  11.6702  13.4919  13.3377
# 7        0 -0.997793  12.8587  10.3696  10.4372  11.6698  13.4916  13.3371
# 8        0 -0.997515  12.8579  10.3693  10.4365  11.6694  13.4914  13.3365
# 9        0 -0.997227  12.8573  10.3692  10.4362  11.6693  13.4912  13.3364
# 10       0 -0.996948  12.8569  10.3695  10.4362  11.6692  13.4913  13.3359
# ...

# %%
y_output=mydata["class"]

# %%
y_output
# Out:
# 0             banana
# 1             banana
# 2             banana
# 3             banana
# 4             banana
# 5             banana
# 6             banana
# 7             banana
# 8             banana
# 9             banana
# 10            banana
# 11            banana
# 12            banana
# 13            banana
# 14            banana
# 15            banana
# 16            banana
# 17            banana
# 18            banana
# 19            banana
# 20            banana
# 21            banana
# 22            banana
# 23            banana
# 24            banana
# 25            banana
# 26            banana
# 27            banana
# 28            banana
# 29            banana
#              ...
# 928961    background
# 928962    background
# 928963    background
# 928964    background
# 928965    background
# 928966    background
# 928967    background
# 928968    background
# 928969    background
# 928970    background
# 928971    background
# 928972    background
# ...

# %%
from sklearn.preprocessing import LabelEncoder,Imputer
im=Imputer(missing_values='NaN',strategy='mean',axis=0)
le=LabelEncoder()
y_output=le.fit_transform(y_output)
print(y_output)
# Out:
# [1 1 1 ... 0 0 0]

# %%
x_input=x_input

# %%
im.fit(x_input)
x_input=im.transform(x_input)
from sklearn.model_selection import train_test_split
print(x_input.shape)
# Out:
# (928991, 14)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_input,y_output,test_size=.40)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
np.isnan(x_train)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
myknn=LogisticRegression()

# %%
mymodel=myknn.fit(x_train,y_train)

# %%
y_pred=myknn.predict(x_test)
from sklearn.metrics import accuracy_score
print( accuracy_score(y_test,y_pred))
# Out:
# 0.7643253309364715
